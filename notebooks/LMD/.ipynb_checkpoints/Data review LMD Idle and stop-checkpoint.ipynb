# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="NorthCorp")
import datetime
import matplotlib.pyplot as plt

# %%
filename = "/home/parth/Machine Learning/Datasets/North Corp/rawfeed_april_0_CAN.csv"
data = pd.read_csv(filename)

# %%
data.head()
# Out:
#    Unnamed: 0  id                   date type         deviceID  sequenceNo  \
# 0           1   8  2019-04-01 00:00:02.0  CAN  359218062578930        4107
# 1           3  16  2019-04-01 00:00:10.0  CAN  359218062578880       22429
# 2           6  48  2019-04-01 00:00:42.0  CAN  359218062576470       15608
# 3           7  51  2019-04-01 00:00:27.0  CAN  359218062581850       20857
# 4          10  71  2019-04-01 00:01:02.0  CAN  359218062578930        4109
#
#    latitude  longitude        utc    hrlfc  ...  engineOperatingHours  \
# 0  21.94126   75.13216  607392002  5708.15  ...               1029.55
# 1  16.76413   80.29130  607392010  2150.79  ...                556.40
# 2  13.28629   75.78487  607392042  3425.60  ...                786.30
# 3  19.46641   73.33467  607392027  5935.49  ...               1129.80
# 4  21.94126   75.13216  607392062  5708.15  ...               1029.55
#
#    powerKeyPos  accPedalIdelSwitch  vehicleSpeed  controlerTrimMode  \
# 0            0                   0          0.00                  0
# 1            0                   0          0.00                  0
# 2            0                   0          0.00                  0
# 3            0                   0         75.23                  0
# 4            0                   0          0.00                  0
#
#    engineOilPressure  engineCoolantTemp  accPedalPosition  tripFuel  live
# 0                  0                 80               0.0   5708.15     1
# 1                  0                 70               0.0   2150.79     1
# 2                  0                 81               0.0   3425.60     1
# 3                312                 84               0.0   5935.49     1
# 4                  0                 80               0.0   5708.15     1
#
# [5 rows x 47 columns]

# %%
data_sort = data.sort_values(["date"]  , ascending=True)
data_sort.drop(columns="Unnamed: 0" , inplace=True)

data_sort["deviceID"] = data_sort["deviceID"].apply(lambda x: "{:.2f}".format(x))

# %%
# case 3(a) Idling

IdleCases = data_sort[data_sort.vehicleSpeed == 0] 
IdleCases = IdleCases[IdleCases.engineSpeed > 0]

# %%
StopCases = data_sort[data_sort.vehicleSpeed == 0]
StopCases = StopCases[StopCases.engineSpeed == 0 ]

# %%
dataRunning = data_sort.copy()
dataRunning["Running"] = np.where( (dataRunning["engineSpeed"] > 0)  , 1 , 0)

# %%
dataRunningId = dataRunning[dataRunning.deviceID == dataRunning.deviceID.unique()[0]]

# %%
dataRunningId["date_object"] = dataRunningId["date"].apply(
    lambda x: datetime.datetime.strptime(x , "%Y-%m-%d %H:%M:%S.0"))
dataRunningId["dateSeconds"] = dataRunningId["date_object"].apply(
    lambda x: (x - datetime.datetime(1970,1,1)).total_seconds() )
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
times = dataRunningId["dateSeconds"].values
was_one = False
result = []
resutlt_latitude= []
resutlt_longitude = []
result_date = []
for index  , time in enumerate(times) :
    if dataRunningId.iloc[index]["Running"] == 1 :
        if not was_one:
            startTime = time
            startDate = dataRunningId.iloc[index]["date"]
        was_one = True
    elif dataRunningId.iloc[index]["Running"] == 0 :
        if was_one :
            result.append(time - startTime)
            result_date.append(startDate)
            resutlt_latitude.append(dataRunningId.iloc[index - 1]["latitude"])
            resutlt_longitude.append(dataRunningId.iloc[index - 1]["longitude"])
        was_one = False

# %%
times = dataRunningId["dateSeconds"].values
was_zero = False
result0 = []
resutlt0_latitude= []
resutlt0_longitude = []
result0_date = []
for index  , time in enumerate(times) :
    if dataRunningId.iloc[index]["Running"] == 0 :
        if not was_zero:
            startTime = time
            startDate = dataRunningId.iloc[index]["date"]
        was_zero = True
    elif dataRunningId.iloc[index]["Running"] == 1 :
        if was_zero :
            result0.append(time - startTime)
            result0_date.append(startDate)
            resutlt0_latitude.append(dataRunningId.iloc[index - 1]["latitude"])
            resutlt0_longitude.append(dataRunningId.iloc[index - 1]["longitude"])
        was_zero = False

# %%
IdleIntervals = pd.DataFrame( data=[np.arange(len(result)) , result_date , result, resutlt_latitude , resutlt_longitude] )
StoppageIntervals = pd.DataFrame( data=[np.arange(len(result0)) , result0_date , result0, resutlt0_latitude , resutlt0_longitude] )

# %%
#result_location_str = [geolocator.reverse(*tup) for tup in resutlt_location]

# %%
def process(intervals):
    intervals = intervals.T
    intervals["Interval ID"] = intervals[0]
    intervals["Date"] = intervals[1]
    intervals["Interval Length"] = intervals[2]
    intervals["Latitude"] = intervals[3]
    intervals["Longitude"] = intervals[4]
    intervals.drop(columns=[0 , 1 , 2 , 3 , 4] , inplace=True)
    return intervals

# %%
IdleIntervals = process(IdleIntervals)
StoppageIntervals = process(StoppageIntervals)

# %%
# Saving All relevant files
base = "/home/parth/Machine Learning/Datasets/North Corp/"

import os

data_sort.to_csv(os.path.join(base , "DataSorted.csv") )
dataRunning.to_csv(os.path.join(base , "dataRunning.csv"))
IdleCases.to_csv(os.path.join(base , "IdleCases.csv"))
StopCases.to_csv(os.path.join(base , "StopCases.csv"))
dataRunningId.to_csv(os.path.join(base , "dataRunningId{}.csv"
                     .format(dataRunningId["deviceID"].unique()[0]) ) )
IdleIntervals.to_csv(os.path.join(base , "IdleIntervals.csv") )
StoppageIntervals.to_csv(os.path.join(base , "StoppageIntervals.csv") )

# %%
def plotter(mi  , ma , intervals):
    plt.rcParams.update({'font.size': 22})
    x = intervals["Date"].values[mi:ma]
    y = intervals["Interval Length"].values[mi:ma]
    y = y.reshape(-1 , 1)
    x = x.reshape(-1 , 1)
    plt.figure(figsize=(25 , 20))
    plt.xlabel("Date")
    plt.ylabel("Idle Time")
    plt.title("Idle Time vs Date")
    plt.hist( x=x  , weights=y , bins=ma-mi)
    plt.show()

# %%
#IdleIntervals

# %%
plotter(5,10 , IdleIntervals)

# %%
shp_file = os.path.join(base , "MMRDA_Manual.shp")

from shapely.geometry import Point ,Polygon
import descartes
import geopandas as gpd

# %%
street_map = gpd.read_file(shp_file)
geometry = [Point(xy) for xy in zip(intervals["Longitude"] , intervals["Latitude"]) ]
crs = { 'init' : 'epsg:4326' }
geo_df = gpd.GeoDataFrame(intervals , crs = crs , geometry=geometry)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ac3a3362240d> in <module>()
#       1 street_map = gpd.read_file(shp_file)
# ----> 2 geometry = [Point(xy) for xy in zip(intervals["Longitude"] , intervals["Latitude"]) ]
#       3 crs = { 'init' : 'epsg:4326' }
#       4 geo_df = gpd.GeoDataFrame(intervals , crs = crs , geometry=geometry)
#
# NameError: name 'intervals' is not defined

# %%
fig , ax = plt.subplots(figsize=(15 , 15))
street_map.plot(ax = ax)
geo_df.plot(ax = ax , markersize = 20 , color = "red"  , marker = "o")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'type', 'deviceID', 'sequenceNo',
#        'latitude', 'longitude', 'utc', 'hrlfc', 'sweetSpot', 'topGear',
#        'sweetSpotPercent', 'seconds', 'minute', 'hour', 'month', 'day', 'year',
#        'minuteOffset', 'hourOffset', 'totalDistance', 'fuelLevel',
#        'amberWarningLamp', 'redStopLamp', 'malfunctionLamp',
#        'flashMalFunctionLamp', 'sPNLSB', 'sPN8_2ndByte', 'failurMode',
#        'sPN3_MSB', 'occurenceCount', 'cCA', 'cCES', 'cCSS', 'engineSpeed',
#        'engineStartMode', 'engineOperatingHours', 'powerKeyPos',
#        'accPedalIdelSwitch', 'vehicleSpeed', 'controlerTrimMode',
#        'engineOilPressure', 'engineCoolantTemp', 'accPedalPosition',
#        'tripFuel', 'live'],
#       dtype='object')

# %%
data_sort.describe()
# Out:
#                  id     sequenceNo       latitude      longitude  \
# count  2.340150e+05  234015.000000  234015.000000  234015.000000
# mean   1.512856e+06   13367.443326      18.389072      76.390352
# std    8.574624e+05    8456.338657       3.881071       3.068584
# min    8.000000e+00       1.000000       9.647800      72.893520
# 25%    7.940285e+05    6078.000000      15.816890      74.326250
# 50%    1.527534e+06   12888.000000      19.260530      75.765790
# 75%    2.257148e+06   20084.000000      20.926810      77.151880
# max    2.948750e+06   30001.000000      27.179820      88.374780
#
#                 utc          hrlfc      sweetSpot        topGear  \
# count  2.340150e+05  234015.000000  234015.000000  234015.000000
# mean   6.088055e+08    4375.972365       6.993060       2.997231
# std    7.631498e+05    1893.714779       0.220296       0.091102
# min    6.071328e+08       0.000000       0.000000       0.000000
# 25%    6.081287e+08    2482.350000       7.000000       3.000000
# 50%    6.089079e+08    3996.460000       7.000000       3.000000
# 75%    6.094701e+08    6136.565000       7.000000       3.000000
# max    6.099840e+08    7391.580000       7.000000       3.000000
#
#        sweetSpotPercent        seconds  ...  engineOperatingHours  \
# count     234015.000000  234015.000000  ...         234015.000000
# mean         254.764630      29.354930  ...            892.200951
# std            7.743648      16.590864  ...            301.915450
# min            0.000000       0.000000  ...              0.000000
# 25%          255.000000      15.000000  ...            619.250000
# 50%          255.000000      30.000000  ...            915.600000
# 75%          255.000000      43.000000  ...           1169.550000
# max          255.000000      59.000000  ...           1400.800000
#
#        powerKeyPos  accPedalIdelSwitch   vehicleSpeed  controlerTrimMode  \
# count     234015.0            234015.0  234015.000000           234015.0
# mean           0.0                 0.0      14.700785                0.0
# std            0.0                 0.0      22.578137                0.0
# min            0.0                 0.0       0.000000                0.0
# 25%            0.0                 0.0       0.000000                0.0
# 50%            0.0                 0.0       0.000000                0.0
# 75%            0.0                 0.0      31.220000                0.0
# max            0.0                 0.0      92.920000                0.0
#
#        engineOilPressure  engineCoolantTemp  accPedalPosition       tripFuel  \
# count      234015.000000      234015.000000          234015.0  234015.000000
# mean           97.439532          75.742337               0.0    3369.808493
# std           131.235883          15.462909               0.0    2256.157375
# min             0.000000           0.000000               0.0       0.000000
# 25%             0.000000          76.000000               0.0    1939.580000
# 50%             0.000000          83.000000               0.0    2598.900000
# 75%           216.000000          85.000000               0.0    6053.820000
# max           604.000000          96.000000               0.0    7391.580000
#
#                 live
# count  234015.000000
# mean        0.955340
# std         0.206556
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 43 columns]

# %%
data_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234015 entries, 28994 to 234014
# Data columns (total 46 columns):
# id                      234015 non-null int64
# date                    234015 non-null object
# type                    234015 non-null object
# deviceID                234015 non-null object
# sequenceNo              234015 non-null int64
# latitude                234015 non-null float64
# longitude               234015 non-null float64
# utc                     234015 non-null int64
# hrlfc                   234015 non-null float64
# sweetSpot               234015 non-null int64
# topGear                 234015 non-null int64
# sweetSpotPercent        234015 non-null int64
# seconds                 234015 non-null int64
# minute                  234015 non-null int64
# hour                    234015 non-null int64
# month                   234015 non-null int64
# day                     234015 non-null int64
# year                    234015 non-null int64
# minuteOffset            234015 non-null int64
# hourOffset              234015 non-null int64
# totalDistance           234015 non-null float64
# fuelLevel               234015 non-null float64
# amberWarningLamp        234015 non-null int64
# redStopLamp             234015 non-null int64
# malfunctionLamp         234015 non-null int64
# flashMalFunctionLamp    234015 non-null int64
# sPNLSB                  234015 non-null int64
# sPN8_2ndByte            234015 non-null int64
# failurMode              234015 non-null int64
# sPN3_MSB                234015 non-null int64
# occurenceCount          234015 non-null int64
# cCA                     234015 non-null int64
# cCES                    234015 non-null int64
# cCSS                    234015 non-null int64
# engineSpeed             234015 non-null float64
# engineStartMode         234015 non-null int64
# engineOperatingHours    234015 non-null float64
# powerKeyPos             234015 non-null int64
# accPedalIdelSwitch      234015 non-null int64
# vehicleSpeed            234015 non-null float64
# controlerTrimMode       234015 non-null int64
# engineOilPressure       234015 non-null int64
# engineCoolantTemp       234015 non-null int64
# accPedalPosition        234015 non-null float64
# tripFuel                234015 non-null float64
# live                    234015 non-null int64
# dtypes: float64(10), int64(33), object(3)
# memory usage: 83.9+ MB

# %%
dataRunningId.iloc[2]
# Out:
# id                                     366728
# date                    2019-03-29 00:02:29.0
# type                                      CAN
# deviceID                   359218062174680.00
# sequenceNo                              11518
# latitude                              19.2237
# longitude                             73.1236
# utc                                 607132949
# hrlfc                                 1842.25
# sweetSpot                                   7
# topGear                                     3
# sweetSpotPercent                          255
# seconds                                    30
# minute                                     28
# hour                                       17
# month                                       3
# day                                        29
# year                                     2019
# minuteOffset                              130
# hourOffset                                130
# totalDistance                         20518.4
# fuelLevel                                60.8
# amberWarningLamp                            0
# redStopLamp                                 0
# malfunctionLamp                             0
# flashMalFunctionLamp                        3
# sPNLSB                                      0
# sPN8_2ndByte                                0
# failurMode                                  0
# sPN3_MSB                                    0
# occurenceCount                              0
# cCA                                         0
# cCES                                        1
# cCSS                                        0
# engineSpeed                            1161.5
# engineStartMode                            15
# engineOperatingHours                   453.35
# powerKeyPos                                 0
# accPedalIdelSwitch                          0
# vehicleSpeed                             15.9
# controlerTrimMode                           0
# engineOilPressure                         196
# engineCoolantTemp                          84
# accPedalPosition                            0
# tripFuel                              1842.25
# live                                        0
# Running                                     1
# date_object               2019-03-29 00:02:29
# dateSeconds                       1.55382e+09
# Name: 29002, dtype: object
